# %%
import pandas as pd

# %%
csv_file = "city_data.csv"
city_data_df = pd.read_csv(csv_file)
city_data_df.head()
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Chokurdakh  70.63  147.92    279.83        57           6        5.56
# 1         Alofi -19.06 -169.92    299.15        83          75        1.50
# 2  Philadelphia  39.95  -75.16    304.26        58          75        7.70
# 3         Vaini -21.20 -175.20    298.15        94          75        5.70
# 4      Flinders -34.58  150.86    286.48        97          49        0.45
#
#   Country        Date  Max Temp (F)
# 0      RU  1591829852         44.02
# 1      NU  1591829852         78.80
# 2      US  1591829588         88.00
# 3      TO  1591829853         77.00
# 4      AU  1591829629         55.99

# %%
html = city_data_df.to_html()

# %%
print(html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Max Temp (F)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Chokurdakh</td>
#       <td>70.63</td>
#       <td>147.92</td>
#       <td>279.83</td>
#       <td>57</td>
#       <td>6</td>
#       <td>5.56</td>
#       <td>RU</td>
#       <td>1591829852</td>
#       <td>44.02</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Alofi</td>
#       <td>-19.06</td>
#       <td>-169.92</td>
#       <td>299.15</td>
#       <td>83</td>
#       <td>75</td>
#       <td>1.50</td>
#       <td>NU</td>
#       <td>1591829852</td>
#       <td>78.80</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Philadelphia</td>
# ...
